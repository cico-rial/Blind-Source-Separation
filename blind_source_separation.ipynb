# %% [markdown]
# Author: Leonardo Chiarioni
# email: leonardo.chiarioni@studio.unibo.it

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist, fashion_mnist
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, BatchNormalization, Activation
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split

import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Blind source separation
#
# This project aims to separate an image, formed as the sum of two images, into its original components.
#
# The two source images, img1 and img2, are drawn from different datasets: MNIST and Fashion-MNIST, respectively.
#
# No preprocessing is allowed. The neural network receives the combined image (img1 + img2) as input and outputs the predicted components (hat_img1,hat_img2).
#
# Performance is evaluated using the mean squared error (MSE) between the predicted and ground-truth images.
#
# Both datasets (MNIST and Fashion-MNIST) are grayscale. For simplicity, all samples are padded to a (32,32) resolution.

# %% [markdown]
# ## Dataset
# The dataset consists of low-resolution grey-scale images (32,32) obtained by averaging pairs of images from mnist and fashion mnist dataset. Each of the training dataset contains $60000$ images, which implies $60000^2$ different possible images. That said, is very hard for our model to overfit the dataset. For this specific reason, we define a very small validation set to test our models during training.

# %%
val_size = 0.1
(mnist_x_train, mnist_y_train), (mnist_x_test, mnist_y_test) = mnist.load_data()
mnist_x_train, mnist_x_val, mnist_y_train, mnist_y_val = train_test_split(mnist_x_train, mnist_y_train, test_size=val_size)
(fashion_mnist_x_train, fashion_mnist_y_train), (fashion_mnist_x_test, fashion_mnist_y_test) = fashion_mnist.load_data()
fashion_mnist_x_train, fashion_mnist_x_val, fashion_mnist_y_train, fashion_mnist_y_val = train_test_split(fashion_mnist_x_train, fashion_mnist_y_train, test_size=val_size)

#normalize and pad
mnist_x_train = np.pad(mnist_x_train,((0,0),(2,2),(2,2)))/255.
mnist_x_val = np.pad(mnist_x_val,((0,0),(2,2),(2,2)))/255.
mnist_x_test = np.pad(mnist_x_test,((0,0),(2,2),(2,2)))/255.
fashion_mnist_x_train = np.pad(fashion_mnist_x_train,((0,0),(2,2),(2,2)))/255.
fashion_mnist_x_val = np.pad(fashion_mnist_x_val,((0,0),(2,2),(2,2)))/255.
fashion_mnist_x_test = np.pad(fashion_mnist_x_test,((0,0),(2,2),(2,2)))/255.


print(f"mnist train size: {np.shape(mnist_x_train)}")
print(f"fashion_mnist train size: {np.shape(fashion_mnist_x_train)}")
print(f"mnist val size: {np.shape(mnist_x_val)}")
print(f"fashion_mnist val size: {np.shape(fashion_mnist_x_val)}")
print(f"mnist test size: {np.shape(mnist_x_test)}")
print(f"fashion_mnist test size: {np.shape(fashion_mnist_x_test)}")
# Out:
# mnist train size: (54000, 32, 32)
# fashion_mnist train size: (54000, 32, 32)
# mnist val size: (6000, 32, 32)
# fashion_mnist val size: (6000, 32, 32)
# mnist test size: (10000, 32, 32)
# fashion_mnist test size: (10000, 32, 32)

# %% [markdown]
# The dataset is provided through a generator:

# %%
def datagenerator(x1,x2,batchsize):
    n1 = x1.shape[0]
    n2 = x2.shape[0]
    while True:
        num1 = np.random.randint(0, n1, batchsize)
        num2 = np.random.randint(0, n2, batchsize)

        x_data = (x1[num1] + x2[num2]) / 2.0
        y_data = (x1[num1], x2[num2])

        yield x_data, y_data

# %% [markdown]
# Let us look at some input-output pairs

# %%
def show_images(x,y1,y2):
    fig, ax = plt.subplots(1,3,figsize=(12,4))
    ax[0].imshow(x,cmap='gray')
    ax[0].title.set_text('Input')
    ax[0].axis('off')
    ax[1].imshow(y1,cmap='gray')
    ax[1].title.set_text('mnist')
    ax[1].axis('off')
    ax[2].imshow(y2,cmap='gray')
    ax[2].title.set_text('fashion_mnist')
    ax[2].axis('off')
    plt.show()

# %%
onegen = datagenerator(mnist_x_test,fashion_mnist_x_test,1)
x,(y1,y2)=next(onegen)
show_images(x[0],y1[0],y2[0])

# %% [markdown]
# ## Architecture
# The objective of the task is to reconstruct the 2 original images starting from their overlapping. An encoder-decoder based network is highly advisable for this task; computing a "compressed" representation of the input through the encoder that is then reconstructed by the decoder, giving 2 images in ouput.
# U-Net is an architecture of this kind, a fully convolutional network. We will start by implementing it from scratch from the [original paper's](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/) architecture:
# <div align="center">
#     <img src="https://production-media.paperswithcode.com/methods/Screen_Shot_2020-07-07_at_9.08.00_PM_rpNArED.png" width="500px">
# </div>
#
# ### Encoder
# The encoder is a feature extractor; it learns a representation of the image through a sequence of encoder blocks, convolutions and downsampling.
# Each encoder block is a stack of 2 3x3 convolution with stride 1, followed by relu and maxpooling with stride 2 for downsampling purposes. The number of channel is doubled after every encoder block.
# ### Bottleneck
# A stack of convolutions that connects the encoder to the decoder.
# ### Decoder
# The decoder is a sequence of blocks, responsible for reconstructing the 2 images by iteratively upsampling the output of the encoder together with skip connections.
# A decoder block performs a transposed convolution with stride 2 to upsample, followed by a concatenation with the skip connection and 2 3x3 convolutions.
# ### Skip connections.
# The skip connections helps the decoder in the reconstruction of the images and allow the gradient to flow.
# ### Batch normalization.
# Despite the original implementation was not considering batch normalization layers after convolutions, modern implementation of the U-NET do include it. We will make use of it between convolutions and activations.
# ### Output.
# Since the output of the network are 2 images, we will apply to the last decoder block 2 parallel 1x1 convolutions in order to output the images with the correct channel dimension (32,32,1). The activation function used here is a sigmoid, since we want each output pixel to be a number between 0 and 1, corresponding to its brightness.

# %%
def unet_baseline():

    def convolutional_block(x, filters, kernel_size=(3, 3), padding="same"):
        x = Conv2D(filters, kernel_size, padding=padding)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(filters, kernel_size, padding=padding)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        return x

    def encoder_block(x, filters, pool_size=(2, 2)):
        x = convolutional_block(x, filters)
        p = MaxPooling2D(pool_size)(x)
        return x, p

    def decoder_block(x, skip, filters, kernel_size=(2, 2), strides=(2, 2), padding="same"):
        x = Conv2DTranspose(filters, kernel_size, strides=strides, padding=padding)(x)
        x = concatenate([x, skip])
        x = convolutional_block(x, filters)
        return x

    inputs = layers.Input(shape=(32,32,1))

    # encoder
    s1, p1 = encoder_block(inputs, filters=64)
    s2, p2 = encoder_block(p1, filters=128)
    s3, p3 = encoder_block(p2, filters=256)
    s4, p4 = encoder_block(p3, filters=512)

    # bottleneck
    b1 = convolutional_block(p4, filters=1024)

    # decoder
    d1 = decoder_block(b1, skip=s4, filters=512)
    d2 = decoder_block(d1, skip=s3, filters=256)
    d3 = decoder_block(d2, skip=s2, filters=128)
    d4 = decoder_block(d3, skip=s1, filters=64)

    # output layers
    output_img1 = Conv2D(1, (1, 1), activation="sigmoid", name="output_img1")(d4)
    output_img2 = Conv2D(1, (1, 1), activation="sigmoid", name="output_img2")(d4)

    model = Model(inputs, [output_img1, output_img2])
    return model

# %% [markdown]
# ## Training
# The dataset is pretty simple and our architecture should be complex enough to be able to reconstruct very precisely the input images. For what we said earlier, overfitting is hardly possible; no real need of regularization techniques like L1/L2 norm or dropout layers.
# What we focused on for the training recipe is, after a bit of hyperparameter tuning:
# - Adam optimizer, with learning rate $= 10^{-3}$
# - learning rate scheduler (ReducedOnPlateau scheduler), the learning rate is halved whenever we reach a plateau in the validation loss, with 5 epochs patience. It was found to be the fundamental component to avoid skipping and exploring promising local minimas of our loss function;
# - early stopping, we will stop training when the validation loss is not increasing for 10 epochs, with 100 epochs at most.
# - steps per epoch = 2000, we fix the number of batches to process each epoch since the dataset is provided by a generator.
# - batch size = 32 the number of images used to update the gradient in the optimization method.

# %%
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6
)
optimizer = Adam(learning_rate=1e-3)
early_stopping =  EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')
max_epochs = 100
steps_per_epoch = 2000

batch_size = 32
train_generator = datagenerator(mnist_x_train, fashion_mnist_x_train, batch_size)
val_generator = datagenerator(mnist_x_val, fashion_mnist_x_val, batch_size)
test_generator = datagenerator(mnist_x_test, fashion_mnist_x_test, 5000)

# %% [markdown]
# ## Evaluation
# The evaluation of the model is done by computing the MSE between the predictions and the ground-truth images. The MSE is computed 10 times on a testset of 5000 images, computing the mean value and the standard deviation. The MSE is also used as the loss function of the task.

# %%
def eval_model(model):
    x, (y1,y2) = next(test_generator)

    pred1,pred2 = model.predict(x)

    pred1 = np.squeeze(pred1)
    pred2 = np.squeeze(pred2)

    return (np.mean((pred1-y1)**2) + np.mean((pred2-y2)**2) / 2)

# %% [markdown]
# # Baseline U-NET
# Let's start by instantiating our baseline U-NET architecture.

# %%
unet_model = unet_baseline()
unet_model.compile(optimizer=optimizer, loss='mse')
unet_model.name = 'unet_baseline'
unet_model.summary()
# Out:
# Model: "unet_baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 32, 32, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 32, 32, 64)     │            640 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 32, 32, 64)     │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 32, 32, 64)     │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 32, 32, 64)     │         36,928 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 32, 32, 64)     │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 16, 16, 64)     │              0 │ activation_1[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 16, 16, 128)    │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 16, 16, 128)    │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 16, 16, 128)    │        147,584 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 16, 16, 128)    │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 8, 8, 128)      │              0 │ activation_3[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 8, 8, 256)      │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 8, 8, 256)      │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 8, 8, 256)      │        590,080 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 8, 8, 256)      │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 4, 4, 256)      │              0 │ activation_5[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 4, 4, 512)      │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 4, 4, 512)      │          2,048 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 4, 4, 512)      │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 4, 4, 512)      │      2,359,808 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 4, 4, 512)      │          2,048 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 4, 4, 512)      │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 2, 2, 512)      │              0 │ activation_7[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 2, 2, 1024)     │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 2, 2, 1024)     │          4,096 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 2, 2, 1024)     │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 2, 2, 1024)     │      9,438,208 │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 2, 2, 1024)     │          4,096 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 2, 2, 1024)     │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 4, 4, 512)      │      2,097,664 │ activation_9[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 4, 4, 1024)     │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ activation_7[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 4, 4, 512)      │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 4, 4, 512)      │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 4, 4, 512)      │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 4, 4, 512)      │      2,359,808 │ activation_10[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 4, 4, 512)      │          2,048 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 4, 4, 512)      │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 8, 8, 256)      │        524,544 │ activation_11[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 8, 8, 512)      │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 8, 8, 256)      │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 8, 8, 256)      │          1,024 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 8, 8, 256)      │        590,080 │ activation_12[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 8, 8, 256)      │          1,024 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 16, 16, 128)    │        131,200 │ activation_13[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 16, 16, 256)    │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 16, 16, 128)    │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 16, 16, 128)    │            512 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 16, 16, 128)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 16, 16, 128)    │        147,584 │ activation_14[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 16, 16, 128)    │            512 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 16, 16, 128)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 32, 32, 64)     │         32,832 │ activation_15[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 32, 32, 128)    │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 32, 32, 64)     │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 32, 32, 64)     │            256 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ activation_16[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 32, 32, 64)     │            256 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_img1 (Conv2D)      │ (None, 32, 32, 1)      │             65 │ activation_17[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_img2 (Conv2D)      │ (None, 32, 32, 1)      │             65 │ activation_17[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,054,210 (118.46 MB)
#  Trainable params: 31,042,434 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %% [markdown]
# It is pretty big! 31 millions parameters, with 4 encoder and decoder blocks.

# %%
checkpoint_filepath = 'unet_baseline.weights.h5'

checkpoint = ModelCheckpoint(   # Let's save the best weights during training
                                filepath=checkpoint_filepath,
                                monitor='val_loss',
                                save_best_only=True,
                                save_weights_only=True,
                                mode='min',
                                verbose=0
                            )

history = unet_model.fit(train_generator,
                         validation_data=val_generator,
                         epochs=max_epochs,
                         steps_per_epoch=steps_per_epoch,
                         validation_steps=500,
                         callbacks = [checkpoint, early_stopping, lr_scheduler])

unet_model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 65s 19ms/step - loss: 0.0181 - output_img1_loss: 0.0112 - output_img2_loss: 0.0069 - val_loss: 0.0031 - val_output_img1_loss: 0.0014 - val_output_img2_loss: 0.0017 - learning_rate: 0.0010
# Epoch 2/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0030 - output_img1_loss: 0.0014 - output_img2_loss: 0.0017 - val_loss: 0.0025 - val_output_img1_loss: 0.0012 - val_output_img2_loss: 0.0013 - learning_rate: 0.0010
# Epoch 3/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0023 - output_img1_loss: 0.0011 - output_img2_loss: 0.0013 - val_loss: 0.0019 - val_output_img1_loss: 8.9813e-04 - val_output_img2_loss: 9.7604e-04 - learning_rate: 0.0010
# Epoch 4/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 0.0020 - output_img1_loss: 9.0021e-04 - output_img2_loss: 0.0011 - val_loss: 0.0093 - val_output_img1_loss: 0.0025 - val_output_img2_loss: 0.0068 - learning_rate: 0.0010
# Epoch 5/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 0.0019 - output_img1_loss: 8.4955e-04 - output_img2_loss: 0.0010 - val_loss: 0.0020 - val_output_img1_loss: 7.3880e-04 - val_output_img2_loss: 0.0013 - learning_rate: 0.0010
# Epoch 6/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 0.0017 - output_img1_loss: 7.8224e-04 - output_img2_loss: 9.2611e-04 - val_loss: 0.0021 - val_output_img1_loss: 8.4050e-04 - val_output_img2_loss: 0.0013 - learning_rate: 0.0010
# Epoch 7/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0016 - output_img1_loss: 7.3161e-04 - output_img2_loss: 8.6198e-04 - val_loss: 0.0014 - val_output_img1_loss: 6.5914e-04 - val_output_img2_loss: 7.3086e-04 - learning_rate: 0.0010
# Epoch 8/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0015 - output_img1_loss: 6.9586e-04 - output_img2_loss: 8.1206e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.4238e-04 - val_output_img2_loss: 6.8422e-04 - learning_rate: 0.0010
# Epoch 9/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0014 - output_img1_loss: 6.6645e-04 - output_img2_loss: 7.6889e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.0580e-04 - val_output_img2_loss: 6.9587e-04 - learning_rate: 0.0010
# Epoch 10/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 0.0013 - output_img1_loss: 6.2555e-04 - output_img2_loss: 7.2345e-04 - val_loss: 0.0014 - val_output_img1_loss: 6.0556e-04 - val_output_img2_loss: 8.3571e-04 - learning_rate: 0.0010
# Epoch 11/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0013 - output_img1_loss: 6.1419e-04 - output_img2_loss: 6.8854e-04 - val_loss: 0.0012 - val_output_img1_loss: 5.8453e-04 - val_output_img2_loss: 6.2849e-04 - learning_rate: 0.0010
# Epoch 12/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 0.0014 - output_img1_loss: 6.4369e-04 - output_img2_loss: 7.2426e-04 - val_loss: 0.0016 - val_output_img1_loss: 6.4055e-04 - val_output_img2_loss: 9.3525e-04 - learning_rate: 0.0010
# Epoch 13/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 0.0012 - output_img1_loss: 5.8149e-04 - output_img2_loss: 6.5606e-04 - val_loss: 0.0012 - val_output_img1_loss: 5.8912e-04 - val_output_img2_loss: 6.3522e-04 - learning_rate: 0.0010
# Epoch 14/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0012 - output_img1_loss: 5.8005e-04 - output_img2_loss: 6.4315e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.4476e-04 - val_output_img2_loss: 5.9572e-04 - learning_rate: 0.0010
# Epoch 15/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0012 - output_img1_loss: 5.6392e-04 - output_img2_loss: 6.3229e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.4782e-04 - val_output_img2_loss: 5.8269e-04 - learning_rate: 0.0010
# Epoch 16/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 0.0012 - output_img1_loss: 5.4672e-04 - output_img2_loss: 6.0866e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.4655e-04 - val_output_img2_loss: 5.9006e-04 - learning_rate: 0.0010
# Epoch 17/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0011 - output_img1_loss: 5.1203e-04 - output_img2_loss: 5.5286e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.0761e-04 - val_output_img2_loss: 5.7337e-04 - learning_rate: 5.0000e-04
# Epoch 18/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0010 - output_img1_loss: 5.0087e-04 - output_img2_loss: 5.3862e-04 - val_loss: 0.0010 - val_output_img1_loss: 5.0176e-04 - val_output_img2_loss: 5.1889e-04 - learning_rate: 5.0000e-04
# Epoch 19/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 0.0010 - output_img1_loss: 4.9915e-04 - output_img2_loss: 5.3656e-04 - val_loss: 0.0010 - val_output_img1_loss: 4.9236e-04 - val_output_img2_loss: 5.5708e-04 - learning_rate: 5.0000e-04
# Epoch 20/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 0.0010 - output_img1_loss: 4.9905e-04 - output_img2_loss: 5.3682e-04 - val_loss: 0.0010 - val_output_img1_loss: 4.9087e-04 - val_output_img2_loss: 5.3458e-04 - learning_rate: 5.0000e-04
# Epoch 21/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 0.0010 - output_img1_loss: 4.8850e-04 - output_img2_loss: 5.2244e-04 - val_loss: 0.0010 - val_output_img1_loss: 4.7057e-04 - val_output_img2_loss: 5.7354e-04 - learning_rate: 5.0000e-04
# Epoch 22/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 0.0010 - output_img1_loss: 4.8672e-04 - output_img2_loss: 5.1738e-04 - val_loss: 0.0010 - val_output_img1_loss: 4.8322e-04 - val_output_img2_loss: 5.2702e-04 - learning_rate: 5.0000e-04
# Epoch 23/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 9.5871e-04 - output_img1_loss: 4.6700e-04 - output_img2_loss: 4.9171e-04 - val_loss: 9.3982e-04 - val_output_img1_loss: 4.6078e-04 - val_output_img2_loss: 4.7904e-04 - learning_rate: 2.5000e-04
# Epoch 24/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 9.5298e-04 - output_img1_loss: 4.6397e-04 - output_img2_loss: 4.8901e-04 - val_loss: 9.7718e-04 - val_output_img1_loss: 4.6659e-04 - val_output_img2_loss: 5.1059e-04 - learning_rate: 2.5000e-04
# Epoch 25/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 9.3587e-04 - output_img1_loss: 4.5549e-04 - output_img2_loss: 4.8038e-04 - val_loss: 9.3874e-04 - val_output_img1_loss: 4.6406e-04 - val_output_img2_loss: 4.7468e-04 - learning_rate: 2.5000e-04
# Epoch 26/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 9.4741e-04 - output_img1_loss: 4.6149e-04 - output_img2_loss: 4.8591e-04 - val_loss: 9.2407e-04 - val_output_img1_loss: 4.5547e-04 - val_output_img2_loss: 4.6860e-04 - learning_rate: 2.5000e-04
# Epoch 27/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 9.4034e-04 - output_img1_loss: 4.5838e-04 - output_img2_loss: 4.8196e-04 - val_loss: 9.4013e-04 - val_output_img1_loss: 4.5360e-04 - val_output_img2_loss: 4.8653e-04 - learning_rate: 2.5000e-04
# Epoch 28/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 9.3162e-04 - output_img1_loss: 4.5413e-04 - output_img2_loss: 4.7749e-04 - val_loss: 9.6224e-04 - val_output_img1_loss: 4.5555e-04 - val_output_img2_loss: 5.0670e-04 - learning_rate: 2.5000e-04
# Epoch 29/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 9.1339e-04 - output_img1_loss: 4.4736e-04 - output_img2_loss: 4.6603e-04 - val_loss: 8.9860e-04 - val_output_img1_loss: 4.4393e-04 - val_output_img2_loss: 4.5467e-04 - learning_rate: 1.2500e-04
# Epoch 30/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 9.1971e-04 - output_img1_loss: 4.4974e-04 - output_img2_loss: 4.6997e-04 - val_loss: 9.0374e-04 - val_output_img1_loss: 4.3935e-04 - val_output_img2_loss: 4.6439e-04 - learning_rate: 1.2500e-04
# Epoch 31/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 9.0046e-04 - output_img1_loss: 4.4052e-04 - output_img2_loss: 4.5994e-04 - val_loss: 9.0954e-04 - val_output_img1_loss: 4.4569e-04 - val_output_img2_loss: 4.6385e-04 - learning_rate: 1.2500e-04
# Epoch 32/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 9.0121e-04 - output_img1_loss: 4.4084e-04 - output_img2_loss: 4.6037e-04 - val_loss: 8.9522e-04 - val_output_img1_loss: 4.4094e-04 - val_output_img2_loss: 4.5428e-04 - learning_rate: 1.2500e-04
# Epoch 33/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 9.0297e-04 - output_img1_loss: 4.4180e-04 - output_img2_loss: 4.6117e-04 - val_loss: 9.0130e-04 - val_output_img1_loss: 4.4381e-04 - val_output_img2_loss: 4.5748e-04 - learning_rate: 1.2500e-04
# Epoch 34/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 8.8455e-04 - output_img1_loss: 4.3395e-04 - output_img2_loss: 4.5060e-04 - val_loss: 8.9175e-04 - val_output_img1_loss: 4.3616e-04 - val_output_img2_loss: 4.5559e-04 - learning_rate: 6.2500e-05
# Epoch 35/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 8.8810e-04 - output_img1_loss: 4.3522e-04 - output_img2_loss: 4.5288e-04 - val_loss: 8.7489e-04 - val_output_img1_loss: 4.3141e-04 - val_output_img2_loss: 4.4348e-04 - learning_rate: 6.2500e-05
# Epoch 36/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.8513e-04 - output_img1_loss: 4.3375e-04 - output_img2_loss: 4.5138e-04 - val_loss: 8.9290e-04 - val_output_img1_loss: 4.3544e-04 - val_output_img2_loss: 4.5746e-04 - learning_rate: 6.2500e-05
# Epoch 37/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.8828e-04 - output_img1_loss: 4.3550e-04 - output_img2_loss: 4.5279e-04 - val_loss: 8.7830e-04 - val_output_img1_loss: 4.3420e-04 - val_output_img2_loss: 4.4410e-04 - learning_rate: 6.2500e-05
# Epoch 38/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 8.8540e-04 - output_img1_loss: 4.3416e-04 - output_img2_loss: 4.5124e-04 - val_loss: 8.7607e-04 - val_output_img1_loss: 4.3215e-04 - val_output_img2_loss: 4.4392e-04 - learning_rate: 6.2500e-05
# Epoch 39/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 8.7739e-04 - output_img1_loss: 4.3044e-04 - output_img2_loss: 4.4694e-04 - val_loss: 8.6934e-04 - val_output_img1_loss: 4.2813e-04 - val_output_img2_loss: 4.4121e-04 - learning_rate: 3.1250e-05
# Epoch 40/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 8.8609e-04 - output_img1_loss: 4.3460e-04 - output_img2_loss: 4.5149e-04 - val_loss: 8.6078e-04 - val_output_img1_loss: 4.2539e-04 - val_output_img2_loss: 4.3539e-04 - learning_rate: 3.1250e-05
# Epoch 41/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.7804e-04 - output_img1_loss: 4.3082e-04 - output_img2_loss: 4.4722e-04 - val_loss: 8.6862e-04 - val_output_img1_loss: 4.2285e-04 - val_output_img2_loss: 4.4577e-04 - learning_rate: 3.1250e-05
# Epoch 42/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 8.8472e-04 - output_img1_loss: 4.3422e-04 - output_img2_loss: 4.5050e-04 - val_loss: 8.6889e-04 - val_output_img1_loss: 4.2849e-04 - val_output_img2_loss: 4.4040e-04 - learning_rate: 3.1250e-05
# Epoch 43/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 8.8428e-04 - output_img1_loss: 4.3414e-04 - output_img2_loss: 4.5014e-04 - val_loss: 8.7232e-04 - val_output_img1_loss: 4.2742e-04 - val_output_img2_loss: 4.4490e-04 - learning_rate: 3.1250e-05
# Epoch 44/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.8602e-04 - output_img1_loss: 4.3527e-04 - output_img2_loss: 4.5075e-04 - val_loss: 8.7628e-04 - val_output_img1_loss: 4.3046e-04 - val_output_img2_loss: 4.4582e-04 - learning_rate: 1.5625e-05
# Epoch 45/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.7366e-04 - output_img1_loss: 4.2877e-04 - output_img2_loss: 4.4489e-04 - val_loss: 8.7496e-04 - val_output_img1_loss: 4.2943e-04 - val_output_img2_loss: 4.4553e-04 - learning_rate: 1.5625e-05
# Epoch 46/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 18ms/step - loss: 8.7332e-04 - output_img1_loss: 4.2887e-04 - output_img2_loss: 4.4445e-04 - val_loss: 8.4749e-04 - val_output_img1_loss: 4.1683e-04 - val_output_img2_loss: 4.3066e-04 - learning_rate: 1.5625e-05
# Epoch 47/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.7007e-04 - output_img1_loss: 4.2721e-04 - output_img2_loss: 4.4286e-04 - val_loss: 8.7586e-04 - val_output_img1_loss: 4.3152e-04 - val_output_img2_loss: 4.4435e-04 - learning_rate: 1.5625e-05
# Epoch 48/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.7002e-04 - output_img1_loss: 4.2737e-04 - output_img2_loss: 4.4265e-04 - val_loss: 8.7463e-04 - val_output_img1_loss: 4.3095e-04 - val_output_img2_loss: 4.4369e-04 - learning_rate: 1.5625e-05
# Epoch 49/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 8.6507e-04 - output_img1_loss: 4.2491e-04 - output_img2_loss: 4.4016e-04 - val_loss: 8.6602e-04 - val_output_img1_loss: 4.2615e-04 - val_output_img2_loss: 4.3987e-04 - learning_rate: 7.8125e-06
# Epoch 50/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.7523e-04 - output_img1_loss: 4.2968e-04 - output_img2_loss: 4.4555e-04 - val_loss: 8.5994e-04 - val_output_img1_loss: 4.2268e-04 - val_output_img2_loss: 4.3726e-04 - learning_rate: 7.8125e-06
# Epoch 51/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 8.7926e-04 - output_img1_loss: 4.3196e-04 - output_img2_loss: 4.4730e-04 - val_loss: 8.5589e-04 - val_output_img1_loss: 4.2208e-04 - val_output_img2_loss: 4.3381e-04 - learning_rate: 7.8125e-06
# Epoch 52/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 8.6024e-04 - output_img1_loss: 4.2233e-04 - output_img2_loss: 4.3791e-04 - val_loss: 8.6767e-04 - val_output_img1_loss: 4.2732e-04 - val_output_img2_loss: 4.4035e-04 - learning_rate: 7.8125e-06
# Epoch 53/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - loss: 8.6810e-04 - output_img1_loss: 4.2666e-04 - output_img2_loss: 4.4144e-04 - val_loss: 8.6001e-04 - val_output_img1_loss: 4.2386e-04 - val_output_img2_loss: 4.3615e-04 - learning_rate: 7.8125e-06
# Epoch 54/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.6937e-04 - output_img1_loss: 4.2690e-04 - output_img2_loss: 4.4247e-04 - val_loss: 8.7330e-04 - val_output_img1_loss: 4.2999e-04 - val_output_img2_loss: 4.4330e-04 - learning_rate: 3.9063e-06
# Epoch 55/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.6886e-04 - output_img1_loss: 4.2683e-04 - output_img2_loss: 4.4203e-04 - val_loss: 8.6830e-04 - val_output_img1_loss: 4.2882e-04 - val_output_img2_loss: 4.3948e-04 - learning_rate: 3.9063e-06
# Epoch 56/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - loss: 8.6391e-04 - output_img1_loss: 4.2448e-04 - output_img2_loss: 4.3943e-04 - val_loss: 8.6168e-04 - val_output_img1_loss: 4.2449e-04 - val_output_img2_loss: 4.3719e-04 - learning_rate: 3.9063e-06
# Epoch 56: early stopping

# %%
def plot_training(history):
    """Plots the training history."""
    plt.figure(figsize=(8, 4))

    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])
    epochs = range(1, len(loss) + 1)

    plt.plot(epochs, loss, label='Training Loss')
    plt.plot(epochs, val_loss, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Mean Squared Error')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_training(history)

# %% [markdown]
# We reached a very low MSE value in both training and validation set. As we can see from the training curves, overfitting hasn't happened.
# Let's evaluate the model on the test set!

# %%
def eval_model_n_times(model, n=10):
    eval_results = []

    for i in range(n):
      eval_results.append(eval_model(model))
    print("mse = ", np.mean(eval_results))
    print("standard deviation = ", np.std(eval_results))

eval_model_n_times(unet_model, n=10)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# mse =  0.000657057590674402
# standard deviation =  1.04188420481508e-05

# %% [markdown]
# Our baseline U-NET performs very good also in the test set, with an $MSE \approx 6.57 \times 10^{-4}$.
# Let's plot some predictions to compare them with the ground-truth images.

# %%
def plot_predictions(model, n):
  test_generator = datagenerator(mnist_x_test,fashion_mnist_x_test,n)
  eval_samples_x, (eval_samples_y1, eval_samples_y2) = next(test_generator)
  y1,y2 = model.predict(eval_samples_x)
  fig, ax = plt.subplots(n,3,figsize=(2*n,n*2))
  for i in range(n):
    ax[i,0].imshow(eval_samples_x[i],cmap='gray')
    ax[i,0].title.set_text('Input')
    ax[i,0].axis('off')
    ax[i,1].imshow(np.concatenate((eval_samples_y1[i],np.squeeze(y1[i])), axis=1) , cmap='gray')
    ax[i,1].title.set_text('mnist vs predicted')
    ax[i,1].axis('off')
    ax[i,2].imshow(np.concatenate((eval_samples_y2[i],np.squeeze(y2[i])), axis=1) ,cmap='gray')
    ax[i,2].title.set_text('fashion mnist vs predicted')
    ax[i,2].axis('off')
  plt.show()

# %%
def plot_predictions(model, n):
  test_generator = datagenerator(mnist_x_test,fashion_mnist_x_test,n)
  eval_samples_x, (eval_samples_y1, eval_samples_y2) = next(test_generator)
  y1,y2 = model.predict(eval_samples_x)
  fig, ax = plt.subplots(n,3,figsize=(2*n,n*2))
  for i in range(n):
    ax[i,0].imshow(eval_samples_x[i],cmap='gray')
    ax[i,0].title.set_text('Input')
    ax[i,0].axis('off')
    ax[i,1].imshow(np.concatenate((eval_samples_y1[i],np.squeeze(y1[i])), axis=1) , cmap='gray')
    ax[i,1].title.set_text('mnist vs predicted')
    ax[i,1].axis('off')
    ax[i,2].imshow(np.concatenate((eval_samples_y2[i],np.squeeze(y2[i])), axis=1) ,cmap='gray')
    ax[i,2].title.set_text('fashion mnist vs predicted')
    ax[i,2].axis('off')
  plt.show()

plot_predictions(unet_model, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %% [markdown]
# We can appreciate the quality of the reconstruction of our model, which performs very good according to a human eye. But our architecture has a very big number of parameters...
# Can we do the same (or even better) with a "simpler" architecture?

# %% [markdown]
# # U-NET 3 encoder-decoder blocks
# Let's reduce the number of encoder and decoder blocks, bringing them to 3. The channel dimension of the bottleneck convolution is lowered accordingly.

# %%
def unet_reduced_1():

    def convolutional_block(x, filters, kernel_size=(3, 3), padding="same"):
        x = Conv2D(filters, kernel_size, padding=padding)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(filters, kernel_size, padding=padding)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        return x

    def encoder_block(x, filters, pool_size=(2, 2)):
        x = convolutional_block(x, filters)
        p = MaxPooling2D(pool_size)(x)
        return x, p

    def decoder_block(x, skip, filters, kernel_size=(2, 2), strides=(2, 2), padding="same"):
        x = Conv2DTranspose(filters, kernel_size, strides=strides, padding=padding)(x)
        x = concatenate([x, skip])
        x = convolutional_block(x, filters)
        return x

    inputs = layers.Input(shape=(32,32,1))

    # encoder
    s1, p1 = encoder_block(inputs, filters=64)
    s2, p2 = encoder_block(p1, filters=128)
    s3, p3 = encoder_block(p2, filters=256)

    # bottleneck
    b1 = convolutional_block(p3, filters=512)

    # decoder
    d1 = decoder_block(b1, skip=s3, filters=256)
    d2 = decoder_block(d1, skip=s2, filters=128)
    d3 = decoder_block(d2, skip=s1, filters=64)

    # output layers
    output_img1 = Conv2D(1, (1, 1), activation="sigmoid", name="output_img1")(d3)
    output_img2 = Conv2D(1, (1, 1), activation="sigmoid", name="output_img2")(d3)

    model = Model(inputs, [output_img1, output_img2])
    return model

# %%
unet_reduced1 = unet_reduced_1()
unet_reduced1.compile(optimizer=optimizer, loss='mse')
unet_reduced1.name = 'unet_reduced_1'
unet_reduced1.summary()
# Out:
# Model: "unet_reduced_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 32, 32, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 32, 32, 64)     │            640 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 32, 32, 64)     │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 32, 32, 64)     │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 32, 32, 64)     │         36,928 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 32, 32, 64)     │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 16, 16, 64)     │              0 │ activation_1[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 16, 16, 128)    │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 16, 16, 128)    │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 16, 16, 128)    │        147,584 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 16, 16, 128)    │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 8, 8, 128)      │              0 │ activation_3[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 8, 8, 256)      │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 8, 8, 256)      │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 8, 8, 256)      │        590,080 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 8, 8, 256)      │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 4, 4, 256)      │              0 │ activation_5[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 4, 4, 512)      │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 4, 4, 512)      │          2,048 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 4, 4, 512)      │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 4, 4, 512)      │      2,359,808 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 4, 4, 512)      │          2,048 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 4, 4, 512)      │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 8, 8, 256)      │        524,544 │ activation_7[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 8, 8, 512)      │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 8, 8, 256)      │      1,179,904 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 8, 8, 256)      │          1,024 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 8, 8, 256)      │        590,080 │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 8, 8, 256)      │          1,024 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 16, 16, 128)    │        131,200 │ activation_9[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 16, 16, 256)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 16, 16, 128)    │        295,040 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 16, 16, 128)    │            512 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 16, 16, 128)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 16, 16, 128)    │        147,584 │ activation_10[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 16, 16, 128)    │            512 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 16, 16, 128)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 32, 32, 64)     │         32,832 │ activation_11[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 32, 32, 128)    │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 32, 32, 64)     │         73,792 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 32, 32, 64)     │            256 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ activation_12[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 32, 32, 64)     │            256 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_img1 (Conv2D)      │ (None, 32, 32, 1)      │             65 │ activation_13[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_img2 (Conv2D)      │ (None, 32, 32, 1)      │             65 │ activation_13[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,707,522 (29.40 MB)
#  Trainable params: 7,701,890 (29.38 MB)
#  Non-trainable params: 5,632 (22.00 KB)

# %% [markdown]
# By using only 3 encoder-decoder blocks we reduced the number of parameters by roughly 4 times, bringing them to 7.7 millions.
# Will it perform as good as the baseline?

# %%
checkpoint_filepath = 'unet_reduced_1.weights.h5'

checkpoint = ModelCheckpoint(
                                filepath=checkpoint_filepath,
                                monitor='val_loss',
                                save_best_only=True,
                                save_weights_only=True,
                                mode='min',
                                verbose=0
                            )

history = unet_reduced1.fit(train_generator,
                            validation_data=val_generator,
                            epochs=max_epochs,
                            steps_per_epoch=steps_per_epoch,
                            validation_steps=500,
                            callbacks = [checkpoint, early_stopping, lr_scheduler])

unet_reduced1.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 0.0150 - output_img1_loss: 0.0078 - output_img2_loss: 0.0072 - val_loss: 0.0032 - val_output_img1_loss: 0.0013 - val_output_img2_loss: 0.0019 - learning_rate: 0.0010
# Epoch 2/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0028 - output_img1_loss: 0.0013 - output_img2_loss: 0.0016 - val_loss: 0.0022 - val_output_img1_loss: 0.0010 - val_output_img2_loss: 0.0012 - learning_rate: 0.0010
# Epoch 3/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0023 - output_img1_loss: 0.0010 - output_img2_loss: 0.0012 - val_loss: 0.0022 - val_output_img1_loss: 9.5735e-04 - val_output_img2_loss: 0.0012 - learning_rate: 0.0010
# Epoch 4/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0020 - output_img1_loss: 8.9225e-04 - output_img2_loss: 0.0011 - val_loss: 0.0016 - val_output_img1_loss: 7.8716e-04 - val_output_img2_loss: 8.5348e-04 - learning_rate: 0.0010
# Epoch 5/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 0.0018 - output_img1_loss: 8.0058e-04 - output_img2_loss: 9.6341e-04 - val_loss: 0.0019 - val_output_img1_loss: 7.7208e-04 - val_output_img2_loss: 0.0011 - learning_rate: 0.0010
# Epoch 6/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0016 - output_img1_loss: 7.4580e-04 - output_img2_loss: 8.6912e-04 - val_loss: 0.0016 - val_output_img1_loss: 7.3355e-04 - val_output_img2_loss: 8.5605e-04 - learning_rate: 0.0010
# Epoch 7/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0015 - output_img1_loss: 7.1146e-04 - output_img2_loss: 8.3009e-04 - val_loss: 0.0015 - val_output_img1_loss: 6.7345e-04 - val_output_img2_loss: 7.9427e-04 - learning_rate: 0.0010
# Epoch 8/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0015 - output_img1_loss: 6.8858e-04 - output_img2_loss: 7.9742e-04 - val_loss: 0.0014 - val_output_img1_loss: 6.4869e-04 - val_output_img2_loss: 7.1501e-04 - learning_rate: 0.0010
# Epoch 9/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0014 - output_img1_loss: 6.4157e-04 - output_img2_loss: 7.4063e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.2086e-04 - val_output_img2_loss: 6.9186e-04 - learning_rate: 0.0010
# Epoch 10/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0014 - output_img1_loss: 6.3244e-04 - output_img2_loss: 7.1769e-04 - val_loss: 0.0014 - val_output_img1_loss: 6.1209e-04 - val_output_img2_loss: 7.4891e-04 - learning_rate: 0.0010
# Epoch 11/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0013 - output_img1_loss: 6.0155e-04 - output_img2_loss: 6.8467e-04 - val_loss: 0.0013 - val_output_img1_loss: 5.8871e-04 - val_output_img2_loss: 6.6228e-04 - learning_rate: 0.0010
# Epoch 12/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0013 - output_img1_loss: 6.0616e-04 - output_img2_loss: 6.8520e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.0302e-04 - val_output_img2_loss: 6.9322e-04 - learning_rate: 0.0010
# Epoch 13/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 0.0013 - output_img1_loss: 5.9471e-04 - output_img2_loss: 6.6754e-04 - val_loss: 0.0013 - val_output_img1_loss: 5.5886e-04 - val_output_img2_loss: 6.9379e-04 - learning_rate: 0.0010
# Epoch 14/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 0.0012 - output_img1_loss: 5.6823e-04 - output_img2_loss: 6.2958e-04 - val_loss: 0.0013 - val_output_img1_loss: 5.5238e-04 - val_output_img2_loss: 7.2026e-04 - learning_rate: 0.0010
# Epoch 15/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0012 - output_img1_loss: 5.5318e-04 - output_img2_loss: 6.1943e-04 - val_loss: 0.0013 - val_output_img1_loss: 5.5611e-04 - val_output_img2_loss: 7.3894e-04 - learning_rate: 0.0010
# Epoch 16/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 0.0011 - output_img1_loss: 5.4394e-04 - output_img2_loss: 6.0023e-04 - val_loss: 0.0012 - val_output_img1_loss: 5.6979e-04 - val_output_img2_loss: 6.6568e-04 - learning_rate: 0.0010
# Epoch 17/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0011 - output_img1_loss: 5.1514e-04 - output_img2_loss: 5.5660e-04 - val_loss: 0.0010 - val_output_img1_loss: 5.0305e-04 - val_output_img2_loss: 5.2086e-04 - learning_rate: 5.0000e-04
# Epoch 18/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0010 - output_img1_loss: 4.9856e-04 - output_img2_loss: 5.3600e-04 - val_loss: 9.8088e-04 - val_output_img1_loss: 4.7940e-04 - val_output_img2_loss: 5.0148e-04 - learning_rate: 5.0000e-04
# Epoch 19/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0010 - output_img1_loss: 4.9001e-04 - output_img2_loss: 5.2658e-04 - val_loss: 0.0010 - val_output_img1_loss: 4.8652e-04 - val_output_img2_loss: 5.1373e-04 - learning_rate: 5.0000e-04
# Epoch 20/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 0.0010 - output_img1_loss: 4.8411e-04 - output_img2_loss: 5.1991e-04 - val_loss: 9.8688e-04 - val_output_img1_loss: 4.8064e-04 - val_output_img2_loss: 5.0624e-04 - learning_rate: 5.0000e-04
# Epoch 21/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 9.9643e-04 - output_img1_loss: 4.8144e-04 - output_img2_loss: 5.1499e-04 - val_loss: 9.6842e-04 - val_output_img1_loss: 4.7925e-04 - val_output_img2_loss: 4.8917e-04 - learning_rate: 5.0000e-04
# Epoch 22/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 9.8485e-04 - output_img1_loss: 4.7650e-04 - output_img2_loss: 5.0835e-04 - val_loss: 0.0010 - val_output_img1_loss: 4.7014e-04 - val_output_img2_loss: 5.3715e-04 - learning_rate: 5.0000e-04
# Epoch 23/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 9.5680e-04 - output_img1_loss: 4.6566e-04 - output_img2_loss: 4.9114e-04 - val_loss: 9.3838e-04 - val_output_img1_loss: 4.5658e-04 - val_output_img2_loss: 4.8180e-04 - learning_rate: 2.5000e-04
# Epoch 24/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 9.4527e-04 - output_img1_loss: 4.6015e-04 - output_img2_loss: 4.8512e-04 - val_loss: 9.3549e-04 - val_output_img1_loss: 4.6016e-04 - val_output_img2_loss: 4.7533e-04 - learning_rate: 2.5000e-04
# Epoch 25/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 9.2799e-04 - output_img1_loss: 4.5192e-04 - output_img2_loss: 4.7607e-04 - val_loss: 9.2326e-04 - val_output_img1_loss: 4.5430e-04 - val_output_img2_loss: 4.6896e-04 - learning_rate: 2.5000e-04
# Epoch 26/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 9.3409e-04 - output_img1_loss: 4.5527e-04 - output_img2_loss: 4.7882e-04 - val_loss: 9.3969e-04 - val_output_img1_loss: 4.5278e-04 - val_output_img2_loss: 4.8691e-04 - learning_rate: 2.5000e-04
# Epoch 27/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 9.2239e-04 - output_img1_loss: 4.4933e-04 - output_img2_loss: 4.7306e-04 - val_loss: 9.1222e-04 - val_output_img1_loss: 4.4231e-04 - val_output_img2_loss: 4.6991e-04 - learning_rate: 2.5000e-04
# Epoch 28/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 9.2140e-04 - output_img1_loss: 4.4906e-04 - output_img2_loss: 4.7234e-04 - val_loss: 9.1057e-04 - val_output_img1_loss: 4.4624e-04 - val_output_img2_loss: 4.6433e-04 - learning_rate: 2.5000e-04
# Epoch 29/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 9.1143e-04 - output_img1_loss: 4.4464e-04 - output_img2_loss: 4.6679e-04 - val_loss: 9.1458e-04 - val_output_img1_loss: 4.4866e-04 - val_output_img2_loss: 4.6593e-04 - learning_rate: 2.5000e-04
# Epoch 30/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.9930e-04 - output_img1_loss: 4.3894e-04 - output_img2_loss: 4.6036e-04 - val_loss: 8.8492e-04 - val_output_img1_loss: 4.3508e-04 - val_output_img2_loss: 4.4984e-04 - learning_rate: 2.5000e-04
# Epoch 31/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.9284e-04 - output_img1_loss: 4.3667e-04 - output_img2_loss: 4.5618e-04 - val_loss: 8.8046e-04 - val_output_img1_loss: 4.3390e-04 - val_output_img2_loss: 4.4656e-04 - learning_rate: 1.2500e-04
# Epoch 32/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.9054e-04 - output_img1_loss: 4.3565e-04 - output_img2_loss: 4.5490e-04 - val_loss: 8.6708e-04 - val_output_img1_loss: 4.2802e-04 - val_output_img2_loss: 4.3905e-04 - learning_rate: 1.2500e-04
# Epoch 33/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.8215e-04 - output_img1_loss: 4.3205e-04 - output_img2_loss: 4.5009e-04 - val_loss: 8.9255e-04 - val_output_img1_loss: 4.3416e-04 - val_output_img2_loss: 4.5839e-04 - learning_rate: 1.2500e-04
# Epoch 34/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.7721e-04 - output_img1_loss: 4.2870e-04 - output_img2_loss: 4.4851e-04 - val_loss: 8.7501e-04 - val_output_img1_loss: 4.3061e-04 - val_output_img2_loss: 4.4440e-04 - learning_rate: 1.2500e-04
# Epoch 35/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.7276e-04 - output_img1_loss: 4.2714e-04 - output_img2_loss: 4.4563e-04 - val_loss: 8.7683e-04 - val_output_img1_loss: 4.2706e-04 - val_output_img2_loss: 4.4976e-04 - learning_rate: 1.2500e-04
# Epoch 36/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.6696e-04 - output_img1_loss: 4.2503e-04 - output_img2_loss: 4.4192e-04 - val_loss: 8.6558e-04 - val_output_img1_loss: 4.2785e-04 - val_output_img2_loss: 4.3773e-04 - learning_rate: 6.2500e-05
# Epoch 37/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.6854e-04 - output_img1_loss: 4.2560e-04 - output_img2_loss: 4.4295e-04 - val_loss: 8.7673e-04 - val_output_img1_loss: 4.3200e-04 - val_output_img2_loss: 4.4474e-04 - learning_rate: 6.2500e-05
# Epoch 38/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.6382e-04 - output_img1_loss: 4.2328e-04 - output_img2_loss: 4.4054e-04 - val_loss: 8.6845e-04 - val_output_img1_loss: 4.2964e-04 - val_output_img2_loss: 4.3881e-04 - learning_rate: 6.2500e-05
# Epoch 39/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.7228e-04 - output_img1_loss: 4.2783e-04 - output_img2_loss: 4.4446e-04 - val_loss: 8.6834e-04 - val_output_img1_loss: 4.2740e-04 - val_output_img2_loss: 4.4095e-04 - learning_rate: 6.2500e-05
# Epoch 40/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.6490e-04 - output_img1_loss: 4.2376e-04 - output_img2_loss: 4.4115e-04 - val_loss: 8.7366e-04 - val_output_img1_loss: 4.3220e-04 - val_output_img2_loss: 4.4146e-04 - learning_rate: 6.2500e-05
# Epoch 41/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.5696e-04 - output_img1_loss: 4.2029e-04 - output_img2_loss: 4.3666e-04 - val_loss: 8.5508e-04 - val_output_img1_loss: 4.2104e-04 - val_output_img2_loss: 4.3404e-04 - learning_rate: 3.1250e-05
# Epoch 42/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.4731e-04 - output_img1_loss: 4.1564e-04 - output_img2_loss: 4.3167e-04 - val_loss: 8.5529e-04 - val_output_img1_loss: 4.2193e-04 - val_output_img2_loss: 4.3336e-04 - learning_rate: 3.1250e-05
# Epoch 43/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.6320e-04 - output_img1_loss: 4.2383e-04 - output_img2_loss: 4.3937e-04 - val_loss: 8.5114e-04 - val_output_img1_loss: 4.1930e-04 - val_output_img2_loss: 4.3184e-04 - learning_rate: 3.1250e-05
# Epoch 44/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.7200e-04 - output_img1_loss: 4.2804e-04 - output_img2_loss: 4.4396e-04 - val_loss: 8.4885e-04 - val_output_img1_loss: 4.1952e-04 - val_output_img2_loss: 4.2933e-04 - learning_rate: 3.1250e-05
# Epoch 45/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.5628e-04 - output_img1_loss: 4.2010e-04 - output_img2_loss: 4.3618e-04 - val_loss: 8.5016e-04 - val_output_img1_loss: 4.1922e-04 - val_output_img2_loss: 4.3094e-04 - learning_rate: 3.1250e-05
# Epoch 46/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.5610e-04 - output_img1_loss: 4.2027e-04 - output_img2_loss: 4.3583e-04 - val_loss: 8.3356e-04 - val_output_img1_loss: 4.1172e-04 - val_output_img2_loss: 4.2184e-04 - learning_rate: 1.5625e-05
# Epoch 47/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.4593e-04 - output_img1_loss: 4.1543e-04 - output_img2_loss: 4.3050e-04 - val_loss: 8.5144e-04 - val_output_img1_loss: 4.2032e-04 - val_output_img2_loss: 4.3112e-04 - learning_rate: 1.5625e-05
# Epoch 48/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.4705e-04 - output_img1_loss: 4.1589e-04 - output_img2_loss: 4.3116e-04 - val_loss: 8.5327e-04 - val_output_img1_loss: 4.2114e-04 - val_output_img2_loss: 4.3213e-04 - learning_rate: 1.5625e-05
# Epoch 49/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.5531e-04 - output_img1_loss: 4.2008e-04 - output_img2_loss: 4.3524e-04 - val_loss: 8.5717e-04 - val_output_img1_loss: 4.2180e-04 - val_output_img2_loss: 4.3536e-04 - learning_rate: 1.5625e-05
# Epoch 50/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.4877e-04 - output_img1_loss: 4.1683e-04 - output_img2_loss: 4.3194e-04 - val_loss: 8.4598e-04 - val_output_img1_loss: 4.1845e-04 - val_output_img2_loss: 4.2753e-04 - learning_rate: 1.5625e-05
# Epoch 51/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.5237e-04 - output_img1_loss: 4.1862e-04 - output_img2_loss: 4.3375e-04 - val_loss: 8.4724e-04 - val_output_img1_loss: 4.1863e-04 - val_output_img2_loss: 4.2861e-04 - learning_rate: 7.8125e-06
# Epoch 52/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.5747e-04 - output_img1_loss: 4.2108e-04 - output_img2_loss: 4.3639e-04 - val_loss: 8.5082e-04 - val_output_img1_loss: 4.2003e-04 - val_output_img2_loss: 4.3079e-04 - learning_rate: 7.8125e-06
# Epoch 53/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 8.4566e-04 - output_img1_loss: 4.1493e-04 - output_img2_loss: 4.3073e-04 - val_loss: 8.4937e-04 - val_output_img1_loss: 4.1796e-04 - val_output_img2_loss: 4.3141e-04 - learning_rate: 7.8125e-06
# Epoch 54/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.5733e-04 - output_img1_loss: 4.2110e-04 - output_img2_loss: 4.3623e-04 - val_loss: 8.5911e-04 - val_output_img1_loss: 4.2312e-04 - val_output_img2_loss: 4.3599e-04 - learning_rate: 7.8125e-06
# Epoch 55/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.5125e-04 - output_img1_loss: 4.1795e-04 - output_img2_loss: 4.3331e-04 - val_loss: 8.3814e-04 - val_output_img1_loss: 4.1372e-04 - val_output_img2_loss: 4.2442e-04 - learning_rate: 7.8125e-06
# Epoch 56/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 8.5622e-04 - output_img1_loss: 4.2097e-04 - output_img2_loss: 4.3526e-04 - val_loss: 8.4690e-04 - val_output_img1_loss: 4.1835e-04 - val_output_img2_loss: 4.2854e-04 - learning_rate: 3.9063e-06
# Epoch 56: early stopping

# %%
plot_training(history)

# %% [markdown]
# The training and validation losses are comparable to the baseline's ones, and again our model didn't overfit the training data.

# %%
eval_model_n_times(unet_reduced1, n=10)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# mse =  0.0006338055103406856
# standard deviation =  9.841039097578757e-06

# %% [markdown]
# The MSE on the testset slightly improved with respect to our baseline, and with way less parameters, setting it to $MSE \approx 6.33 \times 10^{-4}$. Stochasticity might play a role, but it is definetly a good news since we use less parameters and flops.

# %%
plot_predictions(unet_reduced1, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %% [markdown]
# Also the plotted prediction show the output of our model, which is pretty good!
#
#  Can we reduce the number of blocks even more?

# %% [markdown]
# # U-NET 2 encoder-decoder blocks
# Let's lower the number of encoder and decoder blocks to 2, again by changing the number of channels in the bottleneck accordingly.

# %%
def unet_reduced_2():

    def convolutional_block(x, filters, kernel_size=(3, 3), padding="same"):
        x = Conv2D(filters, kernel_size, padding=padding)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(filters, kernel_size, padding=padding)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        return x

    def encoder_block(x, filters, pool_size=(2, 2)):
        x = convolutional_block(x, filters)
        p = MaxPooling2D(pool_size)(x)
        return x, p

    def decoder_block(x, skip, filters, kernel_size=(2, 2), strides=(2, 2), padding="same"):
        x = Conv2DTranspose(filters, kernel_size, strides=strides, padding=padding)(x)
        x = concatenate([x, skip])
        x = convolutional_block(x, filters)
        return x

    inputs = layers.Input(shape=(32,32,1))

    # encoder
    s1, p1 = encoder_block(inputs, filters=64)
    s2, p2 = encoder_block(p1, filters=128)

    # bottleneck
    b1 = convolutional_block(p2, filters=256)

    # decoder
    d1 = decoder_block(b1, skip=s2, filters=128)
    d2 = decoder_block(d1, skip=s1, filters=64)

    # output layers
    output_img1 = Conv2D(1, (1, 1), activation="sigmoid", name="output_img1")(d2)
    output_img2 = Conv2D(1, (1, 1), activation="sigmoid", name="output_img2")(d2)

    model = Model(inputs, [output_img1, output_img2])
    return model

# %%
unet_reduced2 = unet_reduced_2()
unet_reduced2.compile(optimizer=optimizer, loss='mse')
unet_reduced2.name = 'unet_reduced_2'
unet_reduced2.summary()
# Out:
# Model: "unet_reduced_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 32, 32, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 32, 32, 64)     │            640 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 32, 32, 64)     │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 32, 32, 64)     │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 32, 32, 64)     │         36,928 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 32, 32, 64)     │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 16, 16, 64)     │              0 │ activation_1[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 16, 16, 128)    │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 16, 16, 128)    │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 16, 16, 128)    │        147,584 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 16, 16, 128)    │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 8, 8, 128)      │              0 │ activation_3[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 8, 8, 256)      │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 8, 8, 256)      │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 8, 8, 256)      │        590,080 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 8, 8, 256)      │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 128)    │        131,200 │ activation_5[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 256)    │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 16, 16, 128)    │        295,040 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 16, 16, 128)    │            512 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 16, 16, 128)    │        147,584 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 16, 16, 128)    │            512 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 64)     │         32,832 │ activation_7[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 128)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 32, 32, 64)     │         73,792 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 32, 32, 64)     │            256 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 32, 32, 64)     │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 32, 32, 64)     │         36,928 │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 32, 32, 64)     │            256 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 32, 32, 64)     │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_img1 (Conv2D)      │ (None, 32, 32, 1)      │             65 │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_img2 (Conv2D)      │ (None, 32, 32, 1)      │             65 │ activation_9[0][0]     │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,866,882 (7.12 MB)
#  Trainable params: 1,864,322 (7.11 MB)
#  Non-trainable params: 2,560 (10.00 KB)

# %% [markdown]
# The U-NET with 2 encoder-decoder blocks has 17 times less parameters than the baseline, with 1.8 millions. Let's try it out!

# %%
checkpoint_filepath = 'unet_reduced_2.weights.h5'

checkpoint = ModelCheckpoint(
                                filepath=checkpoint_filepath,
                                monitor='val_loss',
                                save_best_only=True,
                                save_weights_only=True,
                                mode='min',
                                verbose=0
                            )

history = unet_reduced2.fit(train_generator,
                            validation_data=val_generator,
                            epochs=max_epochs,
                            steps_per_epoch=steps_per_epoch,
                            validation_steps=500,
                            callbacks = [checkpoint, early_stopping, lr_scheduler])

unet_reduced2.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 60s 23ms/step - loss: 0.0195 - output_img1_loss: 0.0087 - output_img2_loss: 0.0108 - val_loss: 0.0037 - val_output_img1_loss: 0.0016 - val_output_img2_loss: 0.0021 - learning_rate: 0.0010
# Epoch 2/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 45s 22ms/step - loss: 0.0031 - output_img1_loss: 0.0014 - output_img2_loss: 0.0017 - val_loss: 0.0030 - val_output_img1_loss: 0.0012 - val_output_img2_loss: 0.0018 - learning_rate: 0.0010
# Epoch 3/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0024 - output_img1_loss: 0.0011 - output_img2_loss: 0.0013 - val_loss: 0.0022 - val_output_img1_loss: 9.6012e-04 - val_output_img2_loss: 0.0013 - learning_rate: 0.0010
# Epoch 4/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0021 - output_img1_loss: 9.4617e-04 - output_img2_loss: 0.0011 - val_loss: 0.0018 - val_output_img1_loss: 8.3699e-04 - val_output_img2_loss: 9.6706e-04 - learning_rate: 0.0010
# Epoch 5/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0019 - output_img1_loss: 8.4344e-04 - output_img2_loss: 0.0010 - val_loss: 0.0017 - val_output_img1_loss: 7.8909e-04 - val_output_img2_loss: 8.9194e-04 - learning_rate: 0.0010
# Epoch 6/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0017 - output_img1_loss: 7.7855e-04 - output_img2_loss: 9.1351e-04 - val_loss: 0.0022 - val_output_img1_loss: 7.8811e-04 - val_output_img2_loss: 0.0015 - learning_rate: 0.0010
# Epoch 7/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0016 - output_img1_loss: 7.4073e-04 - output_img2_loss: 8.7132e-04 - val_loss: 0.0015 - val_output_img1_loss: 6.9739e-04 - val_output_img2_loss: 7.6698e-04 - learning_rate: 0.0010
# Epoch 8/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0015 - output_img1_loss: 7.0102e-04 - output_img2_loss: 8.1257e-04 - val_loss: 0.0025 - val_output_img1_loss: 0.0010 - val_output_img2_loss: 0.0014 - learning_rate: 0.0010
# Epoch 9/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0015 - output_img1_loss: 7.0228e-04 - output_img2_loss: 8.0467e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.4060e-04 - val_output_img2_loss: 6.8849e-04 - learning_rate: 0.0010
# Epoch 10/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0014 - output_img1_loss: 6.5391e-04 - output_img2_loss: 7.4864e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.2394e-04 - val_output_img2_loss: 6.5562e-04 - learning_rate: 0.0010
# Epoch 11/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0013 - output_img1_loss: 6.2354e-04 - output_img2_loss: 7.0109e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.2237e-04 - val_output_img2_loss: 6.4881e-04 - learning_rate: 0.0010
# Epoch 12/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0013 - output_img1_loss: 6.1484e-04 - output_img2_loss: 6.9124e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.1651e-04 - val_output_img2_loss: 6.9074e-04 - learning_rate: 0.0010
# Epoch 13/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0013 - output_img1_loss: 6.0822e-04 - output_img2_loss: 6.7983e-04 - val_loss: 0.0017 - val_output_img1_loss: 6.2287e-04 - val_output_img2_loss: 0.0010 - learning_rate: 0.0010
# Epoch 14/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0012 - output_img1_loss: 5.8309e-04 - output_img2_loss: 6.4357e-04 - val_loss: 0.0012 - val_output_img1_loss: 6.0304e-04 - val_output_img2_loss: 6.4263e-04 - learning_rate: 0.0010
# Epoch 15/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0011 - output_img1_loss: 5.4294e-04 - output_img2_loss: 5.8719e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.4044e-04 - val_output_img2_loss: 5.6797e-04 - learning_rate: 5.0000e-04
# Epoch 16/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0011 - output_img1_loss: 5.2608e-04 - output_img2_loss: 5.6529e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.1433e-04 - val_output_img2_loss: 5.5748e-04 - learning_rate: 5.0000e-04
# Epoch 17/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0011 - output_img1_loss: 5.2276e-04 - output_img2_loss: 5.6428e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.2375e-04 - val_output_img2_loss: 5.7851e-04 - learning_rate: 5.0000e-04
# Epoch 18/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0011 - output_img1_loss: 5.1297e-04 - output_img2_loss: 5.5145e-04 - val_loss: 0.0013 - val_output_img1_loss: 5.5838e-04 - val_output_img2_loss: 7.7118e-04 - learning_rate: 5.0000e-04
# Epoch 19/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0011 - output_img1_loss: 5.1270e-04 - output_img2_loss: 5.4956e-04 - val_loss: 0.0010 - val_output_img1_loss: 5.0564e-04 - val_output_img2_loss: 5.2681e-04 - learning_rate: 5.0000e-04
# Epoch 20/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0010 - output_img1_loss: 4.9914e-04 - output_img2_loss: 5.3636e-04 - val_loss: 0.0012 - val_output_img1_loss: 5.1382e-04 - val_output_img2_loss: 6.9770e-04 - learning_rate: 5.0000e-04
# Epoch 21/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 0.0010 - output_img1_loss: 4.8932e-04 - output_img2_loss: 5.1987e-04 - val_loss: 0.0010 - val_output_img1_loss: 4.9447e-04 - val_output_img2_loss: 5.1914e-04 - learning_rate: 2.5000e-04
# Epoch 22/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.9031e-04 - output_img1_loss: 4.8147e-04 - output_img2_loss: 5.0884e-04 - val_loss: 9.9165e-04 - val_output_img1_loss: 4.8404e-04 - val_output_img2_loss: 5.0762e-04 - learning_rate: 2.5000e-04
# Epoch 23/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.9008e-04 - output_img1_loss: 4.8120e-04 - output_img2_loss: 5.0888e-04 - val_loss: 9.6206e-04 - val_output_img1_loss: 4.7118e-04 - val_output_img2_loss: 4.9089e-04 - learning_rate: 2.5000e-04
# Epoch 24/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.7867e-04 - output_img1_loss: 4.7576e-04 - output_img2_loss: 5.0291e-04 - val_loss: 9.6147e-04 - val_output_img1_loss: 4.7287e-04 - val_output_img2_loss: 4.8860e-04 - learning_rate: 2.5000e-04
# Epoch 25/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.6382e-04 - output_img1_loss: 4.6875e-04 - output_img2_loss: 4.9507e-04 - val_loss: 9.8013e-04 - val_output_img1_loss: 4.7397e-04 - val_output_img2_loss: 5.0616e-04 - learning_rate: 2.5000e-04
# Epoch 26/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.5646e-04 - output_img1_loss: 4.6611e-04 - output_img2_loss: 4.9035e-04 - val_loss: 9.6665e-04 - val_output_img1_loss: 4.7304e-04 - val_output_img2_loss: 4.9362e-04 - learning_rate: 2.5000e-04
# Epoch 27/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.5015e-04 - output_img1_loss: 4.6219e-04 - output_img2_loss: 4.8795e-04 - val_loss: 9.4974e-04 - val_output_img1_loss: 4.6481e-04 - val_output_img2_loss: 4.8493e-04 - learning_rate: 2.5000e-04
# Epoch 28/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.4296e-04 - output_img1_loss: 4.6095e-04 - output_img2_loss: 4.8201e-04 - val_loss: 9.3149e-04 - val_output_img1_loss: 4.5603e-04 - val_output_img2_loss: 4.7546e-04 - learning_rate: 1.2500e-04
# Epoch 29/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.3009e-04 - output_img1_loss: 4.5452e-04 - output_img2_loss: 4.7557e-04 - val_loss: 9.1952e-04 - val_output_img1_loss: 4.5316e-04 - val_output_img2_loss: 4.6636e-04 - learning_rate: 1.2500e-04
# Epoch 30/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.2660e-04 - output_img1_loss: 4.5316e-04 - output_img2_loss: 4.7344e-04 - val_loss: 9.0765e-04 - val_output_img1_loss: 4.4592e-04 - val_output_img2_loss: 4.6173e-04 - learning_rate: 1.2500e-04
# Epoch 31/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.2280e-04 - output_img1_loss: 4.5110e-04 - output_img2_loss: 4.7170e-04 - val_loss: 9.2278e-04 - val_output_img1_loss: 4.5339e-04 - val_output_img2_loss: 4.6939e-04 - learning_rate: 1.2500e-04
# Epoch 32/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.1278e-04 - output_img1_loss: 4.4627e-04 - output_img2_loss: 4.6651e-04 - val_loss: 9.1940e-04 - val_output_img1_loss: 4.5295e-04 - val_output_img2_loss: 4.6645e-04 - learning_rate: 1.2500e-04
# Epoch 33/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.0483e-04 - output_img1_loss: 4.4310e-04 - output_img2_loss: 4.6173e-04 - val_loss: 9.0416e-04 - val_output_img1_loss: 4.4499e-04 - val_output_img2_loss: 4.5918e-04 - learning_rate: 6.2500e-05
# Epoch 34/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.0675e-04 - output_img1_loss: 4.4385e-04 - output_img2_loss: 4.6290e-04 - val_loss: 9.0690e-04 - val_output_img1_loss: 4.4644e-04 - val_output_img2_loss: 4.6046e-04 - learning_rate: 6.2500e-05
# Epoch 35/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9682e-04 - output_img1_loss: 4.3896e-04 - output_img2_loss: 4.5786e-04 - val_loss: 9.3032e-04 - val_output_img1_loss: 4.4647e-04 - val_output_img2_loss: 4.8385e-04 - learning_rate: 6.2500e-05
# Epoch 36/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.0804e-04 - output_img1_loss: 4.4472e-04 - output_img2_loss: 4.6331e-04 - val_loss: 9.0594e-04 - val_output_img1_loss: 4.4520e-04 - val_output_img2_loss: 4.6074e-04 - learning_rate: 6.2500e-05
# Epoch 37/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.0232e-04 - output_img1_loss: 4.4189e-04 - output_img2_loss: 4.6043e-04 - val_loss: 8.9894e-04 - val_output_img1_loss: 4.4337e-04 - val_output_img2_loss: 4.5557e-04 - learning_rate: 6.2500e-05
# Epoch 38/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9811e-04 - output_img1_loss: 4.4032e-04 - output_img2_loss: 4.5779e-04 - val_loss: 8.8536e-04 - val_output_img1_loss: 4.3462e-04 - val_output_img2_loss: 4.5074e-04 - learning_rate: 3.1250e-05
# Epoch 39/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.0216e-04 - output_img1_loss: 4.4216e-04 - output_img2_loss: 4.6001e-04 - val_loss: 8.8995e-04 - val_output_img1_loss: 4.3597e-04 - val_output_img2_loss: 4.5398e-04 - learning_rate: 3.1250e-05
# Epoch 40/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9740e-04 - output_img1_loss: 4.3986e-04 - output_img2_loss: 4.5753e-04 - val_loss: 9.0067e-04 - val_output_img1_loss: 4.4049e-04 - val_output_img2_loss: 4.6017e-04 - learning_rate: 3.1250e-05
# Epoch 41/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9102e-04 - output_img1_loss: 4.3698e-04 - output_img2_loss: 4.5404e-04 - val_loss: 8.9969e-04 - val_output_img1_loss: 4.4364e-04 - val_output_img2_loss: 4.5605e-04 - learning_rate: 3.1250e-05
# Epoch 42/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9239e-04 - output_img1_loss: 4.3754e-04 - output_img2_loss: 4.5484e-04 - val_loss: 8.9806e-04 - val_output_img1_loss: 4.4009e-04 - val_output_img2_loss: 4.5797e-04 - learning_rate: 3.1250e-05
# Epoch 43/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.7823e-04 - output_img1_loss: 4.3051e-04 - output_img2_loss: 4.4771e-04 - val_loss: 8.8144e-04 - val_output_img1_loss: 4.3517e-04 - val_output_img2_loss: 4.4627e-04 - learning_rate: 3.1250e-05
# Epoch 44/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9495e-04 - output_img1_loss: 4.3875e-04 - output_img2_loss: 4.5620e-04 - val_loss: 9.0989e-04 - val_output_img1_loss: 4.4644e-04 - val_output_img2_loss: 4.6345e-04 - learning_rate: 1.5625e-05
# Epoch 45/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.8841e-04 - output_img1_loss: 4.3555e-04 - output_img2_loss: 4.5286e-04 - val_loss: 8.9502e-04 - val_output_img1_loss: 4.4077e-04 - val_output_img2_loss: 4.5425e-04 - learning_rate: 1.5625e-05
# Epoch 46/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9114e-04 - output_img1_loss: 4.3720e-04 - output_img2_loss: 4.5394e-04 - val_loss: 8.9996e-04 - val_output_img1_loss: 4.4200e-04 - val_output_img2_loss: 4.5796e-04 - learning_rate: 1.5625e-05
# Epoch 47/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.8884e-04 - output_img1_loss: 4.3606e-04 - output_img2_loss: 4.5277e-04 - val_loss: 8.9505e-04 - val_output_img1_loss: 4.3978e-04 - val_output_img2_loss: 4.5527e-04 - learning_rate: 1.5625e-05
# Epoch 48/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9617e-04 - output_img1_loss: 4.3959e-04 - output_img2_loss: 4.5658e-04 - val_loss: 8.8001e-04 - val_output_img1_loss: 4.3303e-04 - val_output_img2_loss: 4.4698e-04 - learning_rate: 1.5625e-05
# Epoch 49/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9163e-04 - output_img1_loss: 4.3758e-04 - output_img2_loss: 4.5405e-04 - val_loss: 8.8564e-04 - val_output_img1_loss: 4.3641e-04 - val_output_img2_loss: 4.4922e-04 - learning_rate: 7.8125e-06
# Epoch 50/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9065e-04 - output_img1_loss: 4.3731e-04 - output_img2_loss: 4.5334e-04 - val_loss: 8.8734e-04 - val_output_img1_loss: 4.3655e-04 - val_output_img2_loss: 4.5079e-04 - learning_rate: 7.8125e-06
# Epoch 51/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9481e-04 - output_img1_loss: 4.3883e-04 - output_img2_loss: 4.5598e-04 - val_loss: 9.0049e-04 - val_output_img1_loss: 4.4365e-04 - val_output_img2_loss: 4.5683e-04 - learning_rate: 7.8125e-06
# Epoch 52/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9016e-04 - output_img1_loss: 4.3670e-04 - output_img2_loss: 4.5346e-04 - val_loss: 8.8001e-04 - val_output_img1_loss: 4.3377e-04 - val_output_img2_loss: 4.4625e-04 - learning_rate: 7.8125e-06
# Epoch 53/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9596e-04 - output_img1_loss: 4.3945e-04 - output_img2_loss: 4.5652e-04 - val_loss: 8.8222e-04 - val_output_img1_loss: 4.3420e-04 - val_output_img2_loss: 4.4802e-04 - learning_rate: 7.8125e-06
# Epoch 54/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.8275e-04 - output_img1_loss: 4.3290e-04 - output_img2_loss: 4.4985e-04 - val_loss: 8.8140e-04 - val_output_img1_loss: 4.3399e-04 - val_output_img2_loss: 4.4742e-04 - learning_rate: 3.9063e-06
# Epoch 55/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 9.0492e-04 - output_img1_loss: 4.4436e-04 - output_img2_loss: 4.6056e-04 - val_loss: 8.9289e-04 - val_output_img1_loss: 4.3985e-04 - val_output_img2_loss: 4.5303e-04 - learning_rate: 3.9063e-06
# Epoch 56/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9488e-04 - output_img1_loss: 4.3905e-04 - output_img2_loss: 4.5583e-04 - val_loss: 8.9262e-04 - val_output_img1_loss: 4.3967e-04 - val_output_img2_loss: 4.5294e-04 - learning_rate: 3.9063e-06
# Epoch 57/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.9539e-04 - output_img1_loss: 4.3934e-04 - output_img2_loss: 4.5605e-04 - val_loss: 8.8820e-04 - val_output_img1_loss: 4.3755e-04 - val_output_img2_loss: 4.5065e-04 - learning_rate: 3.9063e-06
# Epoch 58/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - loss: 8.8638e-04 - output_img1_loss: 4.3521e-04 - output_img2_loss: 4.5117e-04 - val_loss: 8.8210e-04 - val_output_img1_loss: 4.3409e-04 - val_output_img2_loss: 4.4801e-04 - learning_rate: 3.9063e-06
# Epoch 58: early stopping

# %%
plot_training(history)

# %% [markdown]
# Again, the losses are comparable to the previous 2 networks.

# %%
eval_model_n_times(unet_reduced2, n=10)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# mse =  0.0006699277602235174
# standard deviation =  5.831275257532469e-06

# %% [markdown]
# There is a very low difference in the MSE with respect to the other 2 models, the performances here are slightly worse but much more efficient to train compared to the baseline. $MSE \approx 6.69 \times 10^{-4}$.
# Are also the visual prediction as good as before?

# %%
plot_predictions(unet_reduced2, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step

# %% [markdown]
# A human can't spot the difference in terms of quality of the results, so this network performs very good!
# Can we simplify even more the network?

# %% [markdown]
# # U-NET 2 encoder-decoder blocks with lighter convolutions
# Here, convolutional blocks are not 2 stacks of 3x3 convolution, but they exploit:
# - 1x1 convolution;
# - 3x3 convolution;
# - 1x1 convolution.
#
# In this way, we are able to go deeper (3 convolutions instead of 2) but with overall less parameters.
# The idea was taken from [bottleneck residual blocks](https://paperswithcode.com/method/bottleneck-residual-block) (but bottlenecks are not effective in this architecture, so the number of channels is preserved).

# %%
def unet_reduced_3():

    def convolutional_block(x, filters, kernel_size=(3, 3), padding="same"):
        x = Conv2D(filters, (1,1), padding=padding)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(filters, kernel_size, padding=padding)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2D(filters, (1,1), padding=padding)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        return x

    def encoder_block(x, filters, pool_size=(2, 2)):
        x = convolutional_block(x, filters)
        p = MaxPooling2D(pool_size)(x)
        return x, p

    def decoder_block(x, skip, filters, kernel_size=(2, 2), strides=(2, 2), padding="same"):
        x = Conv2DTranspose(filters, kernel_size, strides=strides, padding=padding)(x)
        x = concatenate([x, skip])
        x = convolutional_block(x, filters)
        return x

    inputs = layers.Input(shape=(32,32,1))

    # encoder
    s1, p1 = encoder_block(inputs, filters=64)
    s2, p2 = encoder_block(p1, filters=128)

    # bottleneck
    b1 = convolutional_block(p2, filters=256)

    # decoder
    d1 = decoder_block(b1, skip=s2, filters=128)
    d2 = decoder_block(d1, skip=s1, filters=64)

    # output layers
    output_img1 = Conv2D(1, (1, 1), activation="sigmoid", name="output_img1")(d2)
    output_img2 = Conv2D(1, (1, 1), activation="sigmoid", name="output_img2")(d2)

    model = Model(inputs, [output_img1, output_img2])
    return model

# %%
unet_reduced3 = unet_reduced_3()
unet_reduced3.compile(optimizer=optimizer, loss='mse')
unet_reduced3.name = 'unet_reduced_3'
unet_reduced3.summary()
# Out:
# Model: "unet_reduced_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 32, 32, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 32, 32, 64)     │            128 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 32, 32, 64)     │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 32, 32, 64)     │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 32, 32, 64)     │         36,928 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 32, 32, 64)     │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 32, 32, 64)     │          4,160 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 32, 32, 64)     │            256 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 32, 32, 64)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 16, 16, 64)     │              0 │ activation_2[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 16, 16, 128)    │          8,320 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 16, 16, 128)    │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 16, 16, 128)    │        147,584 │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 16, 16, 128)    │            512 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 16, 16, 128)    │         16,512 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 16, 16, 128)    │            512 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 8, 8, 128)      │              0 │ activation_5[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 8, 8, 256)      │         33,024 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 8, 8, 256)      │          1,024 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 8, 8, 256)      │        590,080 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 8, 8, 256)      │          1,024 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 8, 8, 256)      │         65,792 │ activation_7[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 8, 8, 256)      │          1,024 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 8, 8, 256)      │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 128)    │        131,200 │ activation_8[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 256)    │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 16, 16, 128)    │         32,896 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 16, 16, 128)    │            512 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 16, 16, 128)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 16, 16, 128)    │        147,584 │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 16, 16, 128)    │            512 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 16, 16, 128)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 16, 16, 128)    │         16,512 │ activation_10[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 16, 16, 128)    │            512 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 16, 16, 128)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 64)     │         32,832 │ activation_11[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 128)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 32, 32, 64)     │          8,256 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 32, 32, 64)     │            256 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ activation_12[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 32, 32, 64)     │            256 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 32, 32, 64)     │          4,160 │ activation_13[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 32, 32, 64)     │            256 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_img1 (Conv2D)      │ (None, 32, 32, 1)      │             65 │ activation_14[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_img2 (Conv2D)      │ (None, 32, 32, 1)      │             65 │ activation_14[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,320,706 (5.04 MB)
#  Trainable params: 1,316,866 (5.02 MB)
#  Non-trainable params: 3,840 (15.00 KB)

# %% [markdown]
# We reduced the number of parameters by 23 times with respect to the baseline. Will the model still perform as good as it?

# %%
checkpoint_filepath = 'unet_reduced_3.weights.h5'

checkpoint = ModelCheckpoint(
                                filepath=checkpoint_filepath,
                                monitor='val_loss',
                                save_best_only=True,
                                save_weights_only=True,
                                mode='min',
                                verbose=0
                            )

history = unet_reduced3.fit(train_generator,
                            validation_data=val_generator,
                            epochs=max_epochs,
                            steps_per_epoch=steps_per_epoch,
                            validation_steps=500,
                            callbacks = [checkpoint, early_stopping, lr_scheduler])

unet_reduced3.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 61s 21ms/step - loss: 0.0171 - output_img1_loss: 0.0072 - output_img2_loss: 0.0099 - val_loss: 0.0030 - val_output_img1_loss: 0.0014 - val_output_img2_loss: 0.0016 - learning_rate: 0.0010
# Epoch 2/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0031 - output_img1_loss: 0.0014 - output_img2_loss: 0.0017 - val_loss: 0.0025 - val_output_img1_loss: 0.0011 - val_output_img2_loss: 0.0014 - learning_rate: 0.0010
# Epoch 3/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0024 - output_img1_loss: 0.0011 - output_img2_loss: 0.0013 - val_loss: 0.0041 - val_output_img1_loss: 0.0020 - val_output_img2_loss: 0.0022 - learning_rate: 0.0010
# Epoch 4/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0022 - output_img1_loss: 0.0010 - output_img2_loss: 0.0011 - val_loss: 0.0017 - val_output_img1_loss: 8.0059e-04 - val_output_img2_loss: 9.3375e-04 - learning_rate: 0.0010
# Epoch 5/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0018 - output_img1_loss: 8.6573e-04 - output_img2_loss: 9.6530e-04 - val_loss: 0.0016 - val_output_img1_loss: 7.9799e-04 - val_output_img2_loss: 8.2834e-04 - learning_rate: 0.0010
# Epoch 6/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0017 - output_img1_loss: 8.2158e-04 - output_img2_loss: 9.1181e-04 - val_loss: 0.0018 - val_output_img1_loss: 8.5872e-04 - val_output_img2_loss: 9.1886e-04 - learning_rate: 0.0010
# Epoch 7/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0016 - output_img1_loss: 7.7210e-04 - output_img2_loss: 8.4201e-04 - val_loss: 0.0020 - val_output_img1_loss: 8.5772e-04 - val_output_img2_loss: 0.0012 - learning_rate: 0.0010
# Epoch 8/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0015 - output_img1_loss: 7.2441e-04 - output_img2_loss: 7.8516e-04 - val_loss: 0.0015 - val_output_img1_loss: 7.5667e-04 - val_output_img2_loss: 7.6140e-04 - learning_rate: 0.0010
# Epoch 9/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0015 - output_img1_loss: 7.0194e-04 - output_img2_loss: 7.5451e-04 - val_loss: 0.0014 - val_output_img1_loss: 6.6041e-04 - val_output_img2_loss: 6.9958e-04 - learning_rate: 0.0010
# Epoch 10/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0014 - output_img1_loss: 6.6315e-04 - output_img2_loss: 7.1761e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.4761e-04 - val_output_img2_loss: 6.7076e-04 - learning_rate: 0.0010
# Epoch 11/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0013 - output_img1_loss: 6.4792e-04 - output_img2_loss: 6.8984e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.1271e-04 - val_output_img2_loss: 6.5385e-04 - learning_rate: 0.0010
# Epoch 12/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.0013 - output_img1_loss: 6.3557e-04 - output_img2_loss: 6.7691e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.0868e-04 - val_output_img2_loss: 7.0847e-04 - learning_rate: 0.0010
# Epoch 13/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 0.0013 - output_img1_loss: 6.3390e-04 - output_img2_loss: 6.7164e-04 - val_loss: 0.0017 - val_output_img1_loss: 6.9856e-04 - val_output_img2_loss: 0.0010 - learning_rate: 0.0010
# Epoch 14/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 22ms/step - loss: 0.0013 - output_img1_loss: 6.0746e-04 - output_img2_loss: 6.4339e-04 - val_loss: 0.0013 - val_output_img1_loss: 6.5869e-04 - val_output_img2_loss: 6.8684e-04 - learning_rate: 0.0010
# Epoch 15/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 22ms/step - loss: 0.0012 - output_img1_loss: 5.6920e-04 - output_img2_loss: 5.9027e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.4834e-04 - val_output_img2_loss: 5.8961e-04 - learning_rate: 5.0000e-04
# Epoch 16/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 0.0011 - output_img1_loss: 5.4320e-04 - output_img2_loss: 5.6607e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.3921e-04 - val_output_img2_loss: 5.9094e-04 - learning_rate: 5.0000e-04
# Epoch 17/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 22ms/step - loss: 0.0011 - output_img1_loss: 5.3555e-04 - output_img2_loss: 5.5618e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.2713e-04 - val_output_img2_loss: 5.5647e-04 - learning_rate: 5.0000e-04
# Epoch 18/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 0.0011 - output_img1_loss: 5.3433e-04 - output_img2_loss: 5.5395e-04 - val_loss: 0.0015 - val_output_img1_loss: 6.4901e-04 - val_output_img2_loss: 8.9626e-04 - learning_rate: 5.0000e-04
# Epoch 19/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 22ms/step - loss: 0.0011 - output_img1_loss: 5.2370e-04 - output_img2_loss: 5.4179e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.3265e-04 - val_output_img2_loss: 5.4353e-04 - learning_rate: 5.0000e-04
# Epoch 20/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 0.0011 - output_img1_loss: 5.2455e-04 - output_img2_loss: 5.4214e-04 - val_loss: 0.0011 - val_output_img1_loss: 5.2103e-04 - val_output_img2_loss: 5.8772e-04 - learning_rate: 5.0000e-04
# Epoch 21/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 0.0010 - output_img1_loss: 5.0886e-04 - output_img2_loss: 5.2208e-04 - val_loss: 9.9357e-04 - val_output_img1_loss: 4.8940e-04 - val_output_img2_loss: 5.0418e-04 - learning_rate: 2.5000e-04
# Epoch 22/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 0.0010 - output_img1_loss: 4.9459e-04 - output_img2_loss: 5.0688e-04 - val_loss: 9.9827e-04 - val_output_img1_loss: 4.9291e-04 - val_output_img2_loss: 5.0536e-04 - learning_rate: 2.5000e-04
# Epoch 23/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.9681e-04 - output_img1_loss: 4.9197e-04 - output_img2_loss: 5.0484e-04 - val_loss: 0.0010 - val_output_img1_loss: 4.9581e-04 - val_output_img2_loss: 5.1329e-04 - learning_rate: 2.5000e-04
# Epoch 24/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 0.0010 - output_img1_loss: 4.9831e-04 - output_img2_loss: 5.0989e-04 - val_loss: 9.8124e-04 - val_output_img1_loss: 4.8715e-04 - val_output_img2_loss: 4.9409e-04 - learning_rate: 2.5000e-04
# Epoch 25/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.8164e-04 - output_img1_loss: 4.8497e-04 - output_img2_loss: 4.9667e-04 - val_loss: 0.0010 - val_output_img1_loss: 4.8804e-04 - val_output_img2_loss: 5.2789e-04 - learning_rate: 2.5000e-04
# Epoch 26/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.9205e-04 - output_img1_loss: 4.9003e-04 - output_img2_loss: 5.0201e-04 - val_loss: 0.0010 - val_output_img1_loss: 5.0263e-04 - val_output_img2_loss: 5.1654e-04 - learning_rate: 2.5000e-04
# Epoch 27/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.7306e-04 - output_img1_loss: 4.8162e-04 - output_img2_loss: 4.9144e-04 - val_loss: 9.5206e-04 - val_output_img1_loss: 4.7212e-04 - val_output_img2_loss: 4.7994e-04 - learning_rate: 1.2500e-04
# Epoch 28/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.6229e-04 - output_img1_loss: 4.7658e-04 - output_img2_loss: 4.8571e-04 - val_loss: 9.4824e-04 - val_output_img1_loss: 4.6605e-04 - val_output_img2_loss: 4.8218e-04 - learning_rate: 1.2500e-04
# Epoch 29/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.5298e-04 - output_img1_loss: 4.7171e-04 - output_img2_loss: 4.8127e-04 - val_loss: 9.3135e-04 - val_output_img1_loss: 4.6181e-04 - val_output_img2_loss: 4.6954e-04 - learning_rate: 1.2500e-04
# Epoch 30/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.4724e-04 - output_img1_loss: 4.6912e-04 - output_img2_loss: 4.7812e-04 - val_loss: 9.4856e-04 - val_output_img1_loss: 4.6526e-04 - val_output_img2_loss: 4.8330e-04 - learning_rate: 1.2500e-04
# Epoch 31/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.4688e-04 - output_img1_loss: 4.6911e-04 - output_img2_loss: 4.7777e-04 - val_loss: 9.7382e-04 - val_output_img1_loss: 4.8096e-04 - val_output_img2_loss: 4.9286e-04 - learning_rate: 1.2500e-04
# Epoch 32/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.4514e-04 - output_img1_loss: 4.6853e-04 - output_img2_loss: 4.7662e-04 - val_loss: 9.4163e-04 - val_output_img1_loss: 4.6635e-04 - val_output_img2_loss: 4.7528e-04 - learning_rate: 6.2500e-05
# Epoch 33/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.3863e-04 - output_img1_loss: 4.6516e-04 - output_img2_loss: 4.7347e-04 - val_loss: 9.3129e-04 - val_output_img1_loss: 4.6178e-04 - val_output_img2_loss: 4.6951e-04 - learning_rate: 6.2500e-05
# Epoch 34/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.3310e-04 - output_img1_loss: 4.6264e-04 - output_img2_loss: 4.7046e-04 - val_loss: 9.1872e-04 - val_output_img1_loss: 4.5647e-04 - val_output_img2_loss: 4.6225e-04 - learning_rate: 6.2500e-05
# Epoch 35/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.3810e-04 - output_img1_loss: 4.6515e-04 - output_img2_loss: 4.7295e-04 - val_loss: 9.1235e-04 - val_output_img1_loss: 4.5347e-04 - val_output_img2_loss: 4.5888e-04 - learning_rate: 6.2500e-05
# Epoch 36/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.2585e-04 - output_img1_loss: 4.5907e-04 - output_img2_loss: 4.6677e-04 - val_loss: 9.2616e-04 - val_output_img1_loss: 4.6091e-04 - val_output_img2_loss: 4.6526e-04 - learning_rate: 6.2500e-05
# Epoch 37/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.2423e-04 - output_img1_loss: 4.5840e-04 - output_img2_loss: 4.6583e-04 - val_loss: 9.2662e-04 - val_output_img1_loss: 4.6124e-04 - val_output_img2_loss: 4.6538e-04 - learning_rate: 3.1250e-05
# Epoch 38/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 22ms/step - loss: 9.2803e-04 - output_img1_loss: 4.6058e-04 - output_img2_loss: 4.6745e-04 - val_loss: 9.0019e-04 - val_output_img1_loss: 4.4783e-04 - val_output_img2_loss: 4.5236e-04 - learning_rate: 3.1250e-05
# Epoch 39/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.2645e-04 - output_img1_loss: 4.5951e-04 - output_img2_loss: 4.6694e-04 - val_loss: 9.2847e-04 - val_output_img1_loss: 4.6163e-04 - val_output_img2_loss: 4.6684e-04 - learning_rate: 3.1250e-05
# Epoch 40/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.2011e-04 - output_img1_loss: 4.5652e-04 - output_img2_loss: 4.6358e-04 - val_loss: 9.3357e-04 - val_output_img1_loss: 4.6277e-04 - val_output_img2_loss: 4.7080e-04 - learning_rate: 3.1250e-05
# Epoch 41/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.2485e-04 - output_img1_loss: 4.5895e-04 - output_img2_loss: 4.6591e-04 - val_loss: 9.1648e-04 - val_output_img1_loss: 4.5580e-04 - val_output_img2_loss: 4.6068e-04 - learning_rate: 3.1250e-05
# Epoch 42/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.1241e-04 - output_img1_loss: 4.5278e-04 - output_img2_loss: 4.5963e-04 - val_loss: 9.1209e-04 - val_output_img1_loss: 4.5355e-04 - val_output_img2_loss: 4.5853e-04 - learning_rate: 1.5625e-05
# Epoch 43/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 9.1647e-04 - output_img1_loss: 4.5487e-04 - output_img2_loss: 4.6160e-04 - val_loss: 9.1126e-04 - val_output_img1_loss: 4.5277e-04 - val_output_img2_loss: 4.5849e-04 - learning_rate: 1.5625e-05
# Epoch 44/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 9.1981e-04 - output_img1_loss: 4.5628e-04 - output_img2_loss: 4.6352e-04 - val_loss: 9.2204e-04 - val_output_img1_loss: 4.5830e-04 - val_output_img2_loss: 4.6374e-04 - learning_rate: 1.5625e-05
# Epoch 45/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.1272e-04 - output_img1_loss: 4.5293e-04 - output_img2_loss: 4.5978e-04 - val_loss: 9.1508e-04 - val_output_img1_loss: 4.5528e-04 - val_output_img2_loss: 4.5980e-04 - learning_rate: 1.5625e-05
# Epoch 46/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.2538e-04 - output_img1_loss: 4.5920e-04 - output_img2_loss: 4.6618e-04 - val_loss: 9.1731e-04 - val_output_img1_loss: 4.5625e-04 - val_output_img2_loss: 4.6106e-04 - learning_rate: 1.5625e-05
# Epoch 47/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.1770e-04 - output_img1_loss: 4.5548e-04 - output_img2_loss: 4.6222e-04 - val_loss: 8.9280e-04 - val_output_img1_loss: 4.4419e-04 - val_output_img2_loss: 4.4861e-04 - learning_rate: 7.8125e-06
# Epoch 48/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 9.1012e-04 - output_img1_loss: 4.5169e-04 - output_img2_loss: 4.5842e-04 - val_loss: 9.1780e-04 - val_output_img1_loss: 4.5731e-04 - val_output_img2_loss: 4.6049e-04 - learning_rate: 7.8125e-06
# Epoch 49/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.1257e-04 - output_img1_loss: 4.5296e-04 - output_img2_loss: 4.5961e-04 - val_loss: 9.1415e-04 - val_output_img1_loss: 4.5488e-04 - val_output_img2_loss: 4.5927e-04 - learning_rate: 7.8125e-06
# Epoch 50/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 9.0590e-04 - output_img1_loss: 4.4969e-04 - output_img2_loss: 4.5621e-04 - val_loss: 9.1533e-04 - val_output_img1_loss: 4.5569e-04 - val_output_img2_loss: 4.5964e-04 - learning_rate: 7.8125e-06
# Epoch 51/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.1690e-04 - output_img1_loss: 4.5516e-04 - output_img2_loss: 4.6174e-04 - val_loss: 9.0488e-04 - val_output_img1_loss: 4.5015e-04 - val_output_img2_loss: 4.5473e-04 - learning_rate: 7.8125e-06
# Epoch 52/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.2051e-04 - output_img1_loss: 4.5692e-04 - output_img2_loss: 4.6359e-04 - val_loss: 9.0946e-04 - val_output_img1_loss: 4.5250e-04 - val_output_img2_loss: 4.5696e-04 - learning_rate: 7.8125e-06
# Epoch 53/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.2532e-04 - output_img1_loss: 4.5949e-04 - output_img2_loss: 4.6583e-04 - val_loss: 9.2336e-04 - val_output_img1_loss: 4.5976e-04 - val_output_img2_loss: 4.6360e-04 - learning_rate: 3.9063e-06
# Epoch 54/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 9.0773e-04 - output_img1_loss: 4.5048e-04 - output_img2_loss: 4.5725e-04 - val_loss: 9.0265e-04 - val_output_img1_loss: 4.4931e-04 - val_output_img2_loss: 4.5334e-04 - learning_rate: 3.9063e-06
# Epoch 55/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.1206e-04 - output_img1_loss: 4.5268e-04 - output_img2_loss: 4.5939e-04 - val_loss: 9.0568e-04 - val_output_img1_loss: 4.5045e-04 - val_output_img2_loss: 4.5523e-04 - learning_rate: 3.9063e-06
# Epoch 56/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.1086e-04 - output_img1_loss: 4.5189e-04 - output_img2_loss: 4.5896e-04 - val_loss: 9.2106e-04 - val_output_img1_loss: 4.5840e-04 - val_output_img2_loss: 4.6266e-04 - learning_rate: 3.9063e-06
# Epoch 57/100
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 43s 21ms/step - loss: 9.0719e-04 - output_img1_loss: 4.5037e-04 - output_img2_loss: 4.5682e-04 - val_loss: 9.0788e-04 - val_output_img1_loss: 4.5180e-04 - val_output_img2_loss: 4.5608e-04 - learning_rate: 3.9063e-06
# Epoch 57: early stopping

# %% [markdown]
# Training and validation losses are this time slightly higher, but still in the same order of magnitude.

# %%
plot_training(history)

# %%
eval_model_n_times(unet_reduced3, n=10)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# mse =  0.000680243968825025
# standard deviation =  9.094705132278545e-06

# %% [markdown]
# The MSE on the testset is still very good: $MSE \approx 6.80 \times 10^{-4}$.
# The relative difference (in %) between baseline's MSE and this one is:
# $rel_{diff} = \frac{MSE_{baseline}-MSE_{reduced}}{MSE_{baseline}} \times 100 = 3.5\%$
# which is quite low considering that it has 23 times number of parameters less!

# %%
plot_predictions(unet_reduced3, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step

# %% [markdown]
# The visual prediction are again very good, comparable with the other models.
# ## Conclusions.
# The approach used to tackle the task was to start from a known baseline and iterively simplify the architecture in order to boost the performances and speed up the training, with a simpler network.
# The starting U-NET has 31 millions parameter, with 4 encoder-decoder blocks and reached an $MSE = 6.57 \times 10^{-4}$.
# The lightest U-NET has 1.3 millions parameter, with 2 encoder-decoder blocks and lighter convolutions, reached an $MSE = 6.80 \times 10^{-4}$. Having 23 times less parameters and being 4 times faster in training time, we can say that it is an efficient implementation for the task at hand, especially with low resources at our disposal.
# The best architecture turned out to be the 3 encoder-decoder blocks U-NET, with an $MSE = 6.33 \times 10^{-4}$ and 7.5 millions parameter.
# It is worth to note that hyperparameter tuning is crucial for a fixed architecture, and this process has not been shown but only the final training recipe.
# Overall, we can conclude:
# - The dataset is very simple yet diverse; our model didn't overfit and we reached almost the same results in training and validation set. For this reason, we could have avoided using a validation set and we could have trained the network with the whole dataset, and used the training loss as a flag for early stopping and learning rate decrease.
# - The U-NET is a very effective architecture for this task; we can reduce its complexity by reducing the number of encoder-decoder blocks and/or the convolution to perform inside each convolutional block.
# - Among the tested network, the relative difference between the various MSEs is very low: for this reason the 2 encoder-decoder with lighter convolutions U-NET it is a very good tradeoff between number of parameters, required flops and quality of the results if we have low resources at our disposal.
# - Learning rate scheduler helped exploring better minima of our loss function and allowed us to improve the overall results. More advanced scheduler could have helped in improving the overall performance.
#
# # End.
